# %%
import pandas as pd
import numpy as np

tesla = pd.read_csv('TSLA.csv')
tesla
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2013-01-02    2.333333    2.363333    2.314000    2.357333    2.357333
# 1     2013-01-03    2.345333    2.363333    2.316667    2.318000    2.318000
# 2     2013-01-04    2.320000    2.320000    2.261333    2.293333    2.293333
# 3     2013-01-07    2.320000    2.320000    2.260000    2.289333    2.289333
# 4     2013-01-08    2.300000    2.300000    2.207333    2.245333    2.245333
# ...          ...         ...         ...         ...         ...         ...
# 2513  2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2514  2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2515  2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2516  2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2517  2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#          Volume
# 0      17922000
# 1      11130000
# 2      10110000
# 3       6630000
# 4      19260000
# ...         ...
# 2513  166989700
# 2514  208643400
# 2515  221070500
# 2516  221923300
# 2517  157777300
#
# [2518 rows x 7 columns]

# %%
tesla['Date'] = pd.to_datetime(tesla['Date'])
tesla
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-02    2.333333    2.363333    2.314000    2.357333    2.357333
# 1    2013-01-03    2.345333    2.363333    2.316667    2.318000    2.318000
# 2    2013-01-04    2.320000    2.320000    2.261333    2.293333    2.293333
# 3    2013-01-07    2.320000    2.320000    2.260000    2.289333    2.289333
# 4    2013-01-08    2.300000    2.300000    2.207333    2.245333    2.245333
# ...         ...         ...         ...         ...         ...         ...
# 2513 2022-12-23  126.370003  128.619995  121.019997  123.150002  123.150002
# 2514 2022-12-27  117.500000  119.669998  108.760002  109.099998  109.099998
# 2515 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 2516 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 2517 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
#
#          Volume
# 0      17922000
# 1      11130000
# 2      10110000
# 3       6630000
# 4      19260000
# ...         ...
# 2513  166989700
# 2514  208643400
# 2515  221070500
# 2516  221923300
# 2517  157777300
#
# [2518 rows x 7 columns]

# %%
complete_date_range = pd.date_range(start = '2013-01-01', end = '2023-01-01')
df_dates = pd.DataFrame(complete_date_range, columns=['Date'])
df = pd.merge(df_dates, tesla, on='Date', how='left')
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-01         NaN         NaN         NaN         NaN         NaN
# 1    2013-01-02    2.333333    2.363333    2.314000    2.357333    2.357333
# 2    2013-01-03    2.345333    2.363333    2.316667    2.318000    2.318000
# 3    2013-01-04    2.320000    2.320000    2.261333    2.293333    2.293333
# 4    2013-01-05         NaN         NaN         NaN         NaN         NaN
# ...         ...         ...         ...         ...         ...         ...
# 3648 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 3649 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 3650 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
# 3651 2022-12-31         NaN         NaN         NaN         NaN         NaN
# 3652 2023-01-01         NaN         NaN         NaN         NaN         NaN
#
#            Volume
# 0             NaN
# 1      17922000.0
# 2      11130000.0
# 3      10110000.0
# 4             NaN
# ...           ...
# 3648  221070500.0
# 3649  221923300.0
# 3650  157777300.0
# 3651          NaN
# 3652          NaN
#
# [3653 rows x 7 columns]

# %%
columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

for column in columns:
    df[column].interpolate(method='linear', inplace=True)
df.fillna(method='bfill', inplace=True)
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2013-01-01    2.333333    2.363333    2.314000    2.357333    2.357333
# 1    2013-01-02    2.333333    2.363333    2.314000    2.357333    2.357333
# 2    2013-01-03    2.345333    2.363333    2.316667    2.318000    2.318000
# 3    2013-01-04    2.320000    2.320000    2.261333    2.293333    2.293333
# 4    2013-01-05    2.320000    2.320000    2.260889    2.292000    2.292000
# ...         ...         ...         ...         ...         ...         ...
# 3648 2022-12-28  110.349998  116.269997  108.239998  112.709999  112.709999
# 3649 2022-12-29  120.389999  123.570000  117.500000  121.820000  121.820000
# 3650 2022-12-30  119.949997  124.480003  119.750000  123.180000  123.180000
# 3651 2022-12-31  119.949997  124.480003  119.750000  123.180000  123.180000
# 3652 2023-01-01  119.949997  124.480003  119.750000  123.180000  123.180000
#
#            Volume
# 0      17922000.0
# 1      17922000.0
# 2      11130000.0
# 3      10110000.0
# 4       8950000.0
# ...           ...
# 3648  221070500.0
# 3649  221923300.0
# 3650  157777300.0
# 3651  157777300.0
# 3652  157777300.0
#
# [3653 rows x 7 columns]

# %%
features = df[['Open', 'High', 'Low','Adj Close', 'Volume']]
target = df['Close']

# %%
features
# Out:
#             Open        High         Low   Adj Close       Volume
# 0       2.333333    2.363333    2.314000    2.357333   17922000.0
# 1       2.333333    2.363333    2.314000    2.357333   17922000.0
# 2       2.345333    2.363333    2.316667    2.318000   11130000.0
# 3       2.320000    2.320000    2.261333    2.293333   10110000.0
# 4       2.320000    2.320000    2.260889    2.292000    8950000.0
# ...          ...         ...         ...         ...          ...
# 3648  110.349998  116.269997  108.239998  112.709999  221070500.0
# 3649  120.389999  123.570000  117.500000  121.820000  221923300.0
# 3650  119.949997  124.480003  119.750000  123.180000  157777300.0
# 3651  119.949997  124.480003  119.750000  123.180000  157777300.0
# 3652  119.949997  124.480003  119.750000  123.180000  157777300.0
#
# [3653 rows x 5 columns]

# %%
target
# Out:
# 0         2.357333
# 1         2.357333
# 2         2.318000
# 3         2.293333
# 4         2.292000
#            ...
# 3648    112.709999
# 3649    121.820000
# 3650    123.180000
# 3651    123.180000
# 3652    123.180000
# Name: Close, Length: 3653, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler_features = MinMaxScaler()
features_scaled = scaler_features.fit_transform(features)
scaler_target = MinMaxScaler()
target_scaled = scaler_target.fit_transform(target.values.reshape(-1,1))

# %%
features_scaled.shape, target_scaled.shape
# Out:
# ((3653, 5), (3653, 1))

# %%
def create_sequences(input_data, target_data, sequence_length):
    xs = []
    ys = []
    for i in range(len(input_data)-sequence_length):
        xs.append(input_data[i:i+sequence_length])
        ys.append(target_data[i+sequence_length])
    return np.array(xs), np.array(ys)

# %%
sequence_length = 7
X, y = create_sequences(features_scaled, target_scaled, sequence_length)

# %%
X.shape, y.shape
# Out:
# ((3646, 7, 5), (3646, 1))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2916, 7, 5), (730, 7, 5), (2916, 1), (730, 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout


model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dropout(0.2))
model.add(LSTM(units=50, return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam', loss='mean_squared_error')


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 50)             11200
#
#  dropout (Dropout)           (None, 7, 50)             0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dropout_1 (Dropout)         (None, 50)                0
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 31451 (122.86 KB)
# Trainable params: 31451 (122.86 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=2, validation_split=0.2)
# Out:
# Epoch 1/100
# 73/73 - 4s - loss: 0.0053 - val_loss: 0.0011 - 4s/epoch - 48ms/step
# Epoch 2/100
# 73/73 - 1s - loss: 0.0015 - val_loss: 4.0493e-04 - 579ms/epoch - 8ms/step
# Epoch 3/100
# 73/73 - 0s - loss: 0.0013 - val_loss: 5.0012e-04 - 460ms/epoch - 6ms/step
# Epoch 4/100
# 73/73 - 0s - loss: 0.0013 - val_loss: 7.4051e-04 - 409ms/epoch - 6ms/step
# Epoch 5/100
# 73/73 - 0s - loss: 0.0012 - val_loss: 4.9607e-04 - 421ms/epoch - 6ms/step
# Epoch 6/100
# 73/73 - 0s - loss: 0.0011 - val_loss: 4.4247e-04 - 400ms/epoch - 5ms/step
# Epoch 7/100
# 73/73 - 0s - loss: 0.0011 - val_loss: 6.1339e-04 - 406ms/epoch - 6ms/step
# Epoch 8/100
# 73/73 - 0s - loss: 9.3905e-04 - val_loss: 3.3030e-04 - 422ms/epoch - 6ms/step
# Epoch 9/100
# 73/73 - 0s - loss: 0.0010 - val_loss: 5.1418e-04 - 408ms/epoch - 6ms/step
# Epoch 10/100
# 73/73 - 0s - loss: 0.0010 - val_loss: 3.4311e-04 - 394ms/epoch - 5ms/step
# Epoch 11/100
# 73/73 - 0s - loss: 0.0012 - val_loss: 0.0011 - 414ms/epoch - 6ms/step
# Epoch 12/100
# 73/73 - 0s - loss: 9.7422e-04 - val_loss: 4.9094e-04 - 404ms/epoch - 6ms/step
# Epoch 13/100
# 73/73 - 0s - loss: 9.9986e-04 - val_loss: 3.0723e-04 - 384ms/epoch - 5ms/step
# Epoch 14/100
# 73/73 - 0s - loss: 8.9501e-04 - val_loss: 3.2908e-04 - 413ms/epoch - 6ms/step
# Epoch 15/100
# 73/73 - 0s - loss: 9.4119e-04 - val_loss: 4.2963e-04 - 393ms/epoch - 5ms/step
# Epoch 16/100
# 73/73 - 0s - loss: 9.2870e-04 - val_loss: 3.2689e-04 - 413ms/epoch - 6ms/step
# Epoch 17/100
# 73/73 - 1s - loss: 9.7778e-04 - val_loss: 4.1833e-04 - 592ms/epoch - 8ms/step
# Epoch 18/100
# 73/73 - 0s - loss: 8.6289e-04 - val_loss: 4.2928e-04 - 411ms/epoch - 6ms/step
# Epoch 19/100
# 73/73 - 1s - loss: 8.9319e-04 - val_loss: 3.6572e-04 - 581ms/epoch - 8ms/step
# Epoch 20/100
# 73/73 - 0s - loss: 7.9788e-04 - val_loss: 3.3747e-04 - 399ms/epoch - 5ms/step
# Epoch 21/100
# 73/73 - 1s - loss: 7.7847e-04 - val_loss: 2.7056e-04 - 601ms/epoch - 8ms/step
# Epoch 22/100
# 73/73 - 0s - loss: 8.7893e-04 - val_loss: 4.7112e-04 - 415ms/epoch - 6ms/step
# Epoch 23/100
# 73/73 - 0s - loss: 7.9398e-04 - val_loss: 4.6850e-04 - 420ms/epoch - 6ms/step
# Epoch 24/100
# 73/73 - 0s - loss: 9.0050e-04 - val_loss: 2.6865e-04 - 393ms/epoch - 5ms/step
# Epoch 25/100
# 73/73 - 0s - loss: 8.3568e-04 - val_loss: 2.5466e-04 - 415ms/epoch - 6ms/step
# Epoch 26/100
# 73/73 - 1s - loss: 8.0220e-04 - val_loss: 2.4438e-04 - 561ms/epoch - 8ms/step
# Epoch 27/100
# 73/73 - 1s - loss: 7.7660e-04 - val_loss: 2.8706e-04 - 578ms/epoch - 8ms/step
# Epoch 28/100
# 73/73 - 0s - loss: 7.7097e-04 - val_loss: 2.7835e-04 - 406ms/epoch - 6ms/step
# Epoch 29/100
# 73/73 - 0s - loss: 6.6588e-04 - val_loss: 3.1348e-04 - 407ms/epoch - 6ms/step
# Epoch 30/100
# 73/73 - 0s - loss: 7.5068e-04 - val_loss: 2.8462e-04 - 410ms/epoch - 6ms/step
# Epoch 31/100
# 73/73 - 0s - loss: 7.8448e-04 - val_loss: 2.3321e-04 - 412ms/epoch - 6ms/step
# Epoch 32/100
# 73/73 - 0s - loss: 6.7085e-04 - val_loss: 2.4017e-04 - 410ms/epoch - 6ms/step
# Epoch 33/100
# 73/73 - 0s - loss: 6.4748e-04 - val_loss: 3.1142e-04 - 407ms/epoch - 6ms/step
# Epoch 34/100
# 73/73 - 0s - loss: 7.2895e-04 - val_loss: 4.3727e-04 - 415ms/epoch - 6ms/step
# Epoch 35/100
# 73/73 - 0s - loss: 8.9929e-04 - val_loss: 2.1214e-04 - 402ms/epoch - 6ms/step
# Epoch 36/100
# 73/73 - 0s - loss: 8.0497e-04 - val_loss: 4.0350e-04 - 400ms/epoch - 5ms/step
# Epoch 37/100
# 73/73 - 0s - loss: 6.9010e-04 - val_loss: 2.6532e-04 - 410ms/epoch - 6ms/step
# Epoch 38/100
# 73/73 - 0s - loss: 6.6273e-04 - val_loss: 2.0220e-04 - 405ms/epoch - 6ms/step
# Epoch 39/100
# 73/73 - 0s - loss: 6.7510e-04 - val_loss: 2.1333e-04 - 423ms/epoch - 6ms/step
# Epoch 40/100
# 73/73 - 0s - loss: 6.6424e-04 - val_loss: 3.2155e-04 - 405ms/epoch - 6ms/step
# Epoch 41/100
# 73/73 - 0s - loss: 6.6664e-04 - val_loss: 1.9765e-04 - 422ms/epoch - 6ms/step
# Epoch 42/100
# 73/73 - 0s - loss: 6.7791e-04 - val_loss: 2.2744e-04 - 433ms/epoch - 6ms/step
# Epoch 43/100
# 73/73 - 0s - loss: 5.9742e-04 - val_loss: 2.1228e-04 - 416ms/epoch - 6ms/step
# Epoch 44/100
# 73/73 - 1s - loss: 6.2209e-04 - val_loss: 1.9721e-04 - 587ms/epoch - 8ms/step
# Epoch 45/100
# 73/73 - 0s - loss: 6.7748e-04 - val_loss: 1.9531e-04 - 494ms/epoch - 7ms/step
# Epoch 46/100
# 73/73 - 0s - loss: 7.1057e-04 - val_loss: 1.8993e-04 - 416ms/epoch - 6ms/step
# Epoch 47/100
# 73/73 - 0s - loss: 7.4666e-04 - val_loss: 2.2265e-04 - 404ms/epoch - 6ms/step
# Epoch 48/100
# 73/73 - 0s - loss: 7.2177e-04 - val_loss: 1.9753e-04 - 411ms/epoch - 6ms/step
# Epoch 49/100
# 73/73 - 0s - loss: 6.8579e-04 - val_loss: 2.6601e-04 - 406ms/epoch - 6ms/step
# Epoch 50/100
# 73/73 - 0s - loss: 6.6527e-04 - val_loss: 3.6644e-04 - 414ms/epoch - 6ms/step
# Epoch 51/100
# 73/73 - 1s - loss: 7.3745e-04 - val_loss: 2.6704e-04 - 565ms/epoch - 8ms/step
# Epoch 52/100
# 73/73 - 1s - loss: 6.4036e-04 - val_loss: 3.1497e-04 - 540ms/epoch - 7ms/step
# Epoch 53/100
# 73/73 - 0s - loss: 6.5857e-04 - val_loss: 2.8330e-04 - 421ms/epoch - 6ms/step
# Epoch 54/100
# 73/73 - 0s - loss: 6.2025e-04 - val_loss: 1.9696e-04 - 430ms/epoch - 6ms/step
# Epoch 55/100
# 73/73 - 0s - loss: 6.1132e-04 - val_loss: 1.9007e-04 - 396ms/epoch - 5ms/step
# Epoch 56/100
# 73/73 - 0s - loss: 6.8616e-04 - val_loss: 2.3242e-04 - 408ms/epoch - 6ms/step
# Epoch 57/100
# 73/73 - 0s - loss: 5.9529e-04 - val_loss: 1.7575e-04 - 417ms/epoch - 6ms/step
# Epoch 58/100
# 73/73 - 0s - loss: 6.1776e-04 - val_loss: 1.7741e-04 - 406ms/epoch - 6ms/step
# Epoch 59/100
# 73/73 - 0s - loss: 6.4504e-04 - val_loss: 2.5088e-04 - 417ms/epoch - 6ms/step
# Epoch 60/100
# 73/73 - 0s - loss: 6.4776e-04 - val_loss: 2.8031e-04 - 421ms/epoch - 6ms/step
# Epoch 61/100
# 73/73 - 0s - loss: 7.1898e-04 - val_loss: 1.9236e-04 - 428ms/epoch - 6ms/step
# Epoch 62/100
# 73/73 - 0s - loss: 6.2505e-04 - val_loss: 3.0595e-04 - 415ms/epoch - 6ms/step
# Epoch 63/100
# 73/73 - 0s - loss: 5.9335e-04 - val_loss: 2.4513e-04 - 408ms/epoch - 6ms/step
# Epoch 64/100
# 73/73 - 0s - loss: 5.8651e-04 - val_loss: 1.6001e-04 - 420ms/epoch - 6ms/step
# Epoch 65/100
# 73/73 - 0s - loss: 5.7504e-04 - val_loss: 1.7642e-04 - 426ms/epoch - 6ms/step
# Epoch 66/100
# 73/73 - 0s - loss: 6.2726e-04 - val_loss: 2.2640e-04 - 398ms/epoch - 5ms/step
# Epoch 67/100
# 73/73 - 0s - loss: 6.1485e-04 - val_loss: 1.9197e-04 - 411ms/epoch - 6ms/step
# Epoch 68/100
# 73/73 - 0s - loss: 7.2425e-04 - val_loss: 2.3082e-04 - 405ms/epoch - 6ms/step
# Epoch 69/100
# 73/73 - 0s - loss: 6.8043e-04 - val_loss: 1.8975e-04 - 407ms/epoch - 6ms/step
# Epoch 70/100
# 73/73 - 0s - loss: 6.5384e-04 - val_loss: 3.8425e-04 - 406ms/epoch - 6ms/step
# Epoch 71/100
# 73/73 - 0s - loss: 6.5409e-04 - val_loss: 3.2704e-04 - 423ms/epoch - 6ms/step
# Epoch 72/100
# 73/73 - 0s - loss: 7.1305e-04 - val_loss: 2.1051e-04 - 409ms/epoch - 6ms/step
# Epoch 73/100
# 73/73 - 0s - loss: 6.0508e-04 - val_loss: 1.7415e-04 - 412ms/epoch - 6ms/step
# Epoch 74/100
# 73/73 - 0s - loss: 6.0291e-04 - val_loss: 1.6565e-04 - 408ms/epoch - 6ms/step
# Epoch 75/100
# 73/73 - 0s - loss: 6.1698e-04 - val_loss: 1.5129e-04 - 418ms/epoch - 6ms/step
# Epoch 76/100
# 73/73 - 0s - loss: 6.5104e-04 - val_loss: 1.3449e-04 - 417ms/epoch - 6ms/step
# Epoch 77/100
# 73/73 - 1s - loss: 5.8657e-04 - val_loss: 3.2740e-04 - 593ms/epoch - 8ms/step
# Epoch 78/100
# 73/73 - 1s - loss: 6.1499e-04 - val_loss: 2.6637e-04 - 506ms/epoch - 7ms/step
# Epoch 79/100
# 73/73 - 0s - loss: 5.5581e-04 - val_loss: 2.3873e-04 - 420ms/epoch - 6ms/step
# Epoch 80/100
# 73/73 - 0s - loss: 5.7727e-04 - val_loss: 3.4991e-04 - 395ms/epoch - 5ms/step
# Epoch 81/100
# 73/73 - 0s - loss: 6.5339e-04 - val_loss: 2.1095e-04 - 423ms/epoch - 6ms/step
# Epoch 82/100
# 73/73 - 0s - loss: 6.6767e-04 - val_loss: 3.3210e-04 - 422ms/epoch - 6ms/step
# Epoch 83/100
# 73/73 - 0s - loss: 6.9230e-04 - val_loss: 1.3073e-04 - 406ms/epoch - 6ms/step
# Epoch 84/100
# 73/73 - 0s - loss: 5.6401e-04 - val_loss: 1.4586e-04 - 417ms/epoch - 6ms/step
# Epoch 85/100
# 73/73 - 0s - loss: 6.3753e-04 - val_loss: 1.7781e-04 - 385ms/epoch - 5ms/step
# Epoch 86/100
# 73/73 - 0s - loss: 5.9875e-04 - val_loss: 2.0938e-04 - 415ms/epoch - 6ms/step
# Epoch 87/100
# 73/73 - 1s - loss: 6.3819e-04 - val_loss: 1.8046e-04 - 614ms/epoch - 8ms/step
# Epoch 88/100
# 73/73 - 1s - loss: 5.7412e-04 - val_loss: 1.6307e-04 - 640ms/epoch - 9ms/step
# Epoch 89/100
# 73/73 - 0s - loss: 5.8183e-04 - val_loss: 1.4033e-04 - 404ms/epoch - 6ms/step
# Epoch 90/100
# 73/73 - 1s - loss: 6.7375e-04 - val_loss: 3.0216e-04 - 622ms/epoch - 9ms/step
# Epoch 91/100
# 73/73 - 0s - loss: 5.8891e-04 - val_loss: 1.7824e-04 - 405ms/epoch - 6ms/step
# Epoch 92/100
# 73/73 - 0s - loss: 6.2037e-04 - val_loss: 2.0065e-04 - 391ms/epoch - 5ms/step
# Epoch 93/100
# 73/73 - 0s - loss: 5.7096e-04 - val_loss: 1.8415e-04 - 390ms/epoch - 5ms/step
# Epoch 94/100
# 73/73 - 0s - loss: 6.1602e-04 - val_loss: 1.6195e-04 - 407ms/epoch - 6ms/step
# Epoch 95/100
# 73/73 - 0s - loss: 6.4033e-04 - val_loss: 5.9928e-04 - 415ms/epoch - 6ms/step
# Epoch 96/100
# 73/73 - 0s - loss: 6.0991e-04 - val_loss: 1.4104e-04 - 429ms/epoch - 6ms/step
# Epoch 97/100
# 73/73 - 0s - loss: 6.6955e-04 - val_loss: 2.6415e-04 - 418ms/epoch - 6ms/step
# Epoch 98/100
# 73/73 - 0s - loss: 5.9072e-04 - val_loss: 1.4597e-04 - 403ms/epoch - 6ms/step
# Epoch 99/100
# 73/73 - 0s - loss: 5.1237e-04 - val_loss: 1.2470e-04 - 410ms/epoch - 6ms/step
# Epoch 100/100
# 73/73 - 0s - loss: 5.9811e-04 - val_loss: 1.4042e-04 - 406ms/epoch - 6ms/step

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.show()

# %%
y_pred_whole = model.predict(X)

y_pred_whole_inv = scaler_target.inverse_transform(y_pred_whole)
y_actual_whole_inv = scaler_target.inverse_transform(y)

plt.figure(figsize=(10,6))
plt.plot(y_pred_whole_inv, label='Actual Data', color='blue')
plt.plot(y_actual_whole_inv, label='Predicted Data', color='red')
plt.axvline(x=len(X_train), color='r', linestyle='--', label='Train-Test Split')
plt.title('Tesla Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.show()
# Out:
# 114/114 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math


y_train_pred = model.predict(X_train)
y_train_pred_inv = scaler_target.inverse_transform(y_train_pred)
y_train_inv = scaler_target.inverse_transform(y_train)

y_test_pred = model.predict(X_test)
y_test_pred_inv = scaler_target.inverse_transform(y_test_pred)
y_test_inv = scaler_target.inverse_transform(y_test)


train_mae = mean_absolute_error(y_train_inv, y_train_pred_inv)
train_rmse = math.sqrt(mean_squared_error(y_train_inv, y_train_pred_inv))


test_mae = mean_absolute_error(y_test_inv, y_test_pred_inv)
test_rmse = math.sqrt(mean_squared_error(y_test_inv, y_test_pred_inv))

print(f'Training MAE: {train_mae}')
print(f'Training RMSE: {train_rmse}')
print(f'Testing MAE: {test_mae}')
print(f'Testing RMSE: {test_rmse}')
# Out:
# 92/92 [==============================] - 0s 2ms/step
# 23/23 [==============================] - 0s 3ms/step
# Training MAE: 2.4227288981823896
# Training RMSE: 4.748756507991475
# Testing MAE: 2.6641037338935813
# Testing RMSE: 5.357517413304088
